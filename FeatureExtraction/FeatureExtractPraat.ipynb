# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/CancerVsLaryngitis/FeatureExtraction')

# %%
# %%capture

# !pip install praat-parselmouth

# %%
import pandas as pd
import os
import librosa
import FeatureExtract

from sklearn.model_selection import train_test_split

# %%
def extract_feature_df(filepath, start=0):
    feat_df = pd.DataFrame()
    for subdir, dirs, files in os.walk(filepath):
        for file in files:
            filename = os.fsdecode(file)
            if filename.endswith(".wav"):
                y, sr = librosa.load(subdir+'//'+filename)
                dur = librosa.get_duration(y=y, sr=sr)
                f_id = filename.split('.')[0]
                path = subdir+'//'+filename
                report = FeatureExtract.get_report(path, start=start, end=dur)
                feats = FeatureExtract.get_feats(report, f_id)
                pathology = subdir.split('/')[-1]
                feats['pathology']=pathology

                feat_df = pd.concat([feat_df, feats])
    return feat_df

# %%
data_type = 'TrainSetNotPrepped_a'

# %%
features_df = extract_feature_df(f'/content/drive/MyDrive/CancerVsLaryngitis/DealWithData/{data_type}')

# %%
features_df = features_df.reset_index(drop=True)

# %%
features_df = features_df.rename({'name': 'file'}, axis=1)

# %%
features_df.head()
# Out:
#              file  Median pitch  Mean pitch  Standard deviation  \
# 0  1311-a_n_noisy       168.530     169.103               2.256
# 1   139-a_n_pitch       134.434     134.634               1.157
# 2  1315-a_n_pitch       104.943     104.940               3.051
# 3   139-a_n_noisy       126.815     127.053               1.239
# 4  1315-a_n_noisy        99.041      99.031               3.085
#
#    Minimum pitch  Maximum pitch  Number of pulses  Number of periods  \
# 0        163.253        176.994             174.0              173.0
# 1        132.453        137.835             211.0              210.0
# 2         98.939        114.338             130.0              129.0
# 3        124.866        131.494             199.0              198.0
# 4         92.902        108.977             123.0              122.0
#
#    Mean period  Standard deviation of period  ...  Shimmer (local)  \
# 0     0.005914                      0.000085  ...            2.655
# 1     0.007430                      0.000232  ...            3.672
# 2     0.009528                      0.000279  ...            8.711
# 3     0.007872                      0.000294  ...            5.707
# 4     0.010096                      0.000314  ...            7.146
#
#    Shimmer (local, dB)  Shimmer (apq3)  Shimmer (apq5)  Shimmer (apq11)  \
# 0                0.249           1.376           1.515            2.039
# 1                0.384           2.072           1.872            2.403
# 2                0.871           3.582           6.011            9.426
# 3                0.595           3.122           2.222            2.216
# 4                0.628           3.321           4.832            6.858
#
#    Shimmer (dda)  Mean autocorrelation  Mean noise-to-harmonics ratio  \
# 0          4.128              0.984254                       0.016435
# 1          6.216              0.960431                       0.051513
# 2         10.747              0.917601                       0.102870
# 3          9.366              0.948952                       0.073983
# 4          9.963              0.952935                       0.051534
#
#    Mean harmonics-to-noise ratio   pathology
# 0                         20.300  Laryngitis
# 1                         24.582  Laryngitis
# 2                         13.024  Laryngitis
# 3                         23.849  Laryngitis
# 4                         14.204  Laryngitis
#
# [5 rows x 28 columns]

# %%
max_value=features_df.max()

features_df.fillna(value=max_value, inplace=True)

# %%
from sklearn import preprocessing

# %%
column_list=list(features_df.columns)
column_list=column_list[1:-1]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
features_df[column_list] = min_max_scaler.fit_transform(features_df[column_list])

# %%
features_df.head()
# Out:
#              file  Median pitch  Mean pitch  Standard deviation  \
# 0  1311-a_n_noisy      0.309028    0.301840            0.016766
# 1   139-a_n_pitch      0.194737    0.185766            0.006426
# 2  1315-a_n_pitch      0.095882    0.085771            0.024246
# 3   139-a_n_noisy      0.169197    0.160236            0.007198
# 4  1315-a_n_noisy      0.076098    0.065872            0.024566
#
#    Minimum pitch  Maximum pitch  Number of pulses  Number of periods  \
# 0       0.374535       0.183043          0.322160           0.322160
# 1       0.255965       0.105578          0.391061           0.391061
# 2       0.126947       0.059095          0.240223           0.240223
# 3       0.226758       0.093034          0.368715           0.368715
# 4       0.103706       0.048490          0.227188           0.227188
#
#    Mean period  Standard deviation of period  ...  Shimmer (local)  \
# 0     0.324018                      0.020991  ...         0.071395
# 1     0.477129                      0.066832  ...         0.114512
# 2     0.689073                      0.081367  ...         0.328147
# 3     0.521798                      0.086271  ...         0.200789
# 4     0.746489                      0.092408  ...         0.261797
#
#    Shimmer (local, dB)  Shimmer (apq3)  Shimmer (apq5)  Shimmer (apq11)  \
# 0             0.081216        0.073189        0.039233         0.055821
# 1             0.148480        0.125488        0.054556         0.072544
# 2             0.391131        0.238954        0.232219         0.395204
# 3             0.253612        0.204388        0.069580         0.063953
# 4             0.270055        0.219342        0.181611         0.277221
#
#    Shimmer (dda)  Mean autocorrelation  Mean noise-to-harmonics ratio  \
# 0       0.073214              0.967847                       0.017597
# 1       0.125513              0.915965                       0.057547
# 2       0.239004              0.822689                       0.116036
# 3       0.204413              0.890966                       0.083137
# 4       0.219367              0.899640                       0.057570
#
#    Mean harmonics-to-noise ratio   pathology
# 0                       0.629444  Laryngitis
# 1                       0.766965  Laryngitis
# 2                       0.395767  Laryngitis
# 3                       0.743424  Laryngitis
# 4                       0.433664  Laryngitis
#
# [5 rows x 28 columns]

# %%
features_df.shape
# Out:
# (320, 28)

# %%
features_df.to_csv(f'/content/drive/MyDrive/CancerVsLaryngitis/FeatureSets/NotPrepped/praat_{data_type}.csv')

# %%
features_df = extract_feature_df('/content/drive/MyDrive/CancerVsLaryngitis/TestSet/')

# %%
features_df = features_df.reset_index(drop=True)

# %%
features_df = features_df.rename({'name': 'file'}, axis=1)

# %%
features_df.head()
# Out:
#           file  Median pitch  Mean pitch  Standard deviation  Minimum pitch  \
# 0  2402-phrase       137.872     136.679              16.078         77.495
# 1  1403-phrase       121.156     166.510             133.346         75.312
# 2   820-phrase       134.320     142.037              47.573         75.898
# 3  1451-phrase       132.661     130.038              22.421         79.357
# 4  2343-phrase       184.644     177.509              35.420         96.278
#
#    Maximum pitch  Number of pulses  Number of periods  Mean period  \
# 0        167.353             185.0              180.0     0.007344
# 1        601.335             245.0              200.0     0.006931
# 2        242.298             205.0              197.0     0.007066
# 3        161.956             206.0              200.0     0.007741
# 4        260.245             382.0              377.0     0.005622
#
#    Standard deviation of period  ...  Shimmer (local)  Shimmer (local, dB)  \
# 0                      0.000982  ...            9.399                0.887
# 1                      0.003098  ...           12.924                1.271
# 2                      0.002501  ...           10.407                1.128
# 3                      0.001538  ...            8.910                0.995
# 4                      0.001187  ...           13.165                1.137
#
#    Shimmer (apq3)  Shimmer (apq5)  Shimmer (apq11)  Shimmer (dda)  \
# 0           2.962           5.235           11.599          8.886
# 1           5.218           7.909           11.339         15.653
# 2           3.123           5.299            8.252          9.369
# 3           2.997           4.123            8.296          8.991
# 4           6.101           7.158           11.186         18.304
#
#    Mean autocorrelation  Mean noise-to-harmonics ratio  \
# 0              0.941574                       0.069793
# 1              0.838872                       0.247572
# 2              0.884008                       0.149943
# 3              0.901992                       0.130894
# 4              0.902721                       0.135460
#
#    Mean harmonics-to-noise ratio  pathology
# 0                         14.824     Cancer
# 1                         10.733     Cancer
# 2                         10.776     Cancer
# 3                         13.516     Cancer
# 4                         12.354     Cancer
#
# [5 rows x 28 columns]

# %%
features_df[column_list] = min_max_scaler.transform(features_df[column_list])

# %%
features_df.head()
# Out:
#           file  Median pitch  Mean pitch  Standard deviation  Minimum pitch  \
# 0  2402-phrase      0.145569    0.161868            0.031745       0.068851
# 1  1403-phrase      0.087200    0.281119            0.744088       0.054916
# 2   820-phrase      0.133166    0.183287            0.223061       0.058657
# 3  1451-phrase      0.127373    0.135321            0.070276       0.080737
# 4  2343-phrase      0.308886    0.325088            0.149238       0.188750
#
#    Maximum pitch  Number of pulses  Number of periods  Mean period  \
# 0       0.088376          0.210216           0.226141     0.577655
# 1       0.988288          0.328094           0.267635     0.523147
# 2       0.243783          0.249509           0.261411     0.540982
# 3       0.077184          0.251473           0.267635     0.630262
# 4       0.280998          0.597250           0.634855     0.350118
#
#    Standard deviation of period  ...  Shimmer (local)  Shimmer (local, dB)  \
# 0                      0.191522  ...         0.242257             0.276642
# 1                      0.944018  ...         0.432448             0.556934
# 2                      0.732002  ...         0.296644             0.452555
# 3                      0.389411  ...         0.215874             0.355474
# 4                      0.264343  ...         0.445452             0.459124
#
#    Shimmer (apq3)  Shimmer (apq5)  Shimmer (apq11)  Shimmer (dda)  \
# 0        0.157063        0.190702         0.174703       0.157042
# 1        0.364397        0.343423         0.168848       0.364358
# 2        0.171859        0.194357         0.099322       0.171839
# 3        0.160279        0.127192         0.100313       0.160259
# 4        0.445547        0.300531         0.165402       0.445575
#
#    Mean autocorrelation  Mean noise-to-harmonics ratio  \
# 0              0.935168                       0.043677
# 1              0.642786                       0.321359
# 2              0.771283                       0.168867
# 3              0.822482                       0.139114
# 4              0.824557                       0.146246
#
#    Mean harmonics-to-noise ratio  pathology
# 0                       0.706753     Cancer
# 1                       0.479197     Cancer
# 2                       0.481589     Cancer
# 3                       0.633997     Cancer
# 4                       0.569363     Cancer
#
# [5 rows x 28 columns]

# %%
features_df.shape
# Out:
# (40, 28)

# %%
features_df.to_csv('/content/drive/MyDrive/CancerVsLaryngitis/FeatureSets/praat_test.csv')
