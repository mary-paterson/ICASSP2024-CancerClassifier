# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# permutation feature importance with knn for classification
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, balanced_accuracy_score, recall_score, precision_score
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
feature_set='open_smile'

# %%
train_df=pd.read_csv(f'/content/drive/MyDrive/CancerVsLaryngitis/FeatureSets/{feature_set}_train_aug.csv', index_col=0)
train_df.head()
# Out:
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                           0.379874                                0.817824
# 1                           0.485891                                0.588287
# 2                           0.463621                                0.685634
# 3                           0.424624                                0.782267
# 4                           0.131559                                0.340813
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                    0.281838
# 1                                    0.360461
# 2                                    0.381071
# 3                                    0.333405
# 4                                    0.225926
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                    0.336330
# 1                                    0.563639
# 2                                    0.428877
# ...

# %%
X = train_df.drop(['file', 'pathology'], axis=1)
y = train_df['pathology']

# %%
test_df=pd.read_csv(f'/content/drive/MyDrive/CancerVsLaryngitis/FeatureSets/{feature_set}_test.csv', index_col=0)
test_df.head()
# Out:
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                           0.658482                                0.360999
# 1                           0.471188                                0.729519
# 2                           0.292079                                0.397211
# 3                           0.191277                                0.553764
# 4                           0.240744                                0.248325
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                    0.602823
# 1                                    0.341417
# 2                                    0.329320
# 3                                    0.227985
# 4                                    0.367926
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                    0.713071
# 1                                    0.663479
# 2                                    0.313193
# ...

# %%
X_test = test_df.drop(['file', 'pathology'], axis=1)
y_test = test_df['pathology']

# %%
importances = mutual_info_classif(X, y)

# %%
importances_df = pd.DataFrame(importances, columns=['Importance'])
importances_df['Feature']=X.columns

# %%
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf', 'linear', 'sigmoid', 'poly']}

grid = GridSearchCV(SVC(random_state=42), param_grid, refit = True, verbose = 3)

# %%
feat_list = list(importances_df.sort_values(by='Importance', ascending=False)['Feature'])

# %%
i=27


print(len(feat_list[:i]))
X=train_df[feat_list[:i]]
X_test=test_df[feat_list[:i]]

grid.fit(X, y)
grid_predictions = grid.predict(X_test)
accuracy=balanced_accuracy_score(y_test, grid_predictions)
precision=precision_score(y_test, grid_predictions, pos_label='Cancer')
recall=recall_score(y_test, grid_predictions, pos_label='Cancer')
# Out:
# 27
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.766 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.766 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.734 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.859 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.719 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.812 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.781 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.688 total time=   0.0s
# ...

# %%
print(accuracy)
print(precision)
print(recall)
# Out:
# 0.8571428571428572
# 1.0
# 0.7142857142857143

# %%
results_df = test_df[['file', 'pathology']]
results_df['prediction']=grid_predictions
results_df
# Out:
# <ipython-input-35-aa2fa8848297>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df['prediction']=grid_predictions
#                file   pathology  prediction
# 0   1047-phrase.wav      Cancer  Laryngitis
# 1   1245-phrase.wav      Cancer      Cancer
# 2   1383-phrase.wav      Cancer      Cancer
# 3   1391-phrase.wav      Cancer      Cancer
# 4   1403-phrase.wav      Cancer      Cancer
# 5   1416-phrase.wav      Cancer      Cancer
# 6   1451-phrase.wav      Cancer      Cancer
# 7   1472-phrase.wav      Cancer      Cancer
# 8   1649-phrase.wav      Cancer      Cancer
# 9   1714-phrase.wav      Cancer  Laryngitis
# 10  1814-phrase.wav      Cancer  Laryngitis
# 11  2343-phrase.wav      Cancer      Cancer
# ...

# %%
results_df.to_csv(f'/content/drive/MyDrive/CancerVsLaryngitis/FeatureSets/best_{feature_set}_results.csv')
